# %%
import pandas as pd

# %%
nba_pie = pd.read_csv("../data/nba_2017_pie.csv")

# %%
nba_pie.describe()
# Out:
#               AGE          GP           W           L         MIN      OFFRTG  \
# count  486.000000  486.000000  486.000000  486.000000  486.000000  486.000000
# mean    26.847737   53.781893   26.870370   26.911523   19.899588  103.924897
# std      4.355997   24.838733   15.577994   14.272257    9.060969    8.883965
# min     19.000000    1.000000    0.000000    1.000000    0.800000    0.000000
# 25%     24.000000   35.250000   15.000000   16.000000   12.725000  102.000000
# 50%     26.000000   62.500000   27.000000   28.000000   19.100000  104.600000
# 75%     30.000000   75.000000   38.000000   37.000000   27.000000  107.700000
# max     40.000000   82.000000   66.000000   59.000000   37.800000  130.800000
#
#            DEFRTG      NETRTG        AST%      AST/TO   AST RATIO       OREB%  \
# count  486.000000  486.000000  486.000000  486.000000  486.000000  486.000000
# mean   106.002469   -2.074074   13.316667    1.535021   16.044650    5.003909
# ...
