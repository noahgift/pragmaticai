# %%
import pandas as pd

# %%
nba = pd.read_csv("../data/nba_2017_br.csv")

# %%
nba.describe()
# Out:
#                Rk         Age           G          GS          MP          FG  \
# count  486.000000  486.000000  486.000000  486.000000  486.000000  486.000000
# mean   243.500000   26.405350   53.781893   25.308642   19.900206    3.120165
# std    140.440379    4.345194   24.838733   28.715875    9.059629    2.158294
# min      1.000000   19.000000    1.000000    0.000000    1.000000    0.000000
# 25%    122.250000   23.000000   35.250000    1.000000   12.800000    1.500000
# 50%    243.500000   26.000000   62.500000   11.000000   19.100000    2.500000
# 75%    364.750000   29.000000   75.000000   49.750000   27.000000    4.200000
# max    486.000000   40.000000   82.000000   82.000000   37.800000   10.300000
#
#               FGA         FG%          3P         3PA     ...             FT%  \
# count  486.000000  485.000000  486.000000  486.000000     ...      471.000000
# mean     6.913992    0.441278    0.768107    2.184568     ...        0.741155
# ...
